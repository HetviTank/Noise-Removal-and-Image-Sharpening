# %%
# !pip install google-colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.4 MB/s eta 0:00:00
# ...

# %%
#Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('/content/images (1).jpg')

#Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Create the sharpening kernel
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

# Sharpen the image
sharpened_image = cv2.filter2D(image, -1, kernel)

#Save the image
cv2.imwrite('sharpened_image.jpg', sharpened_image)

#Plot the sharpened image
plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)
plt.show()

# %%
import cv2
import numpy as np

# load path of the image
original_image = cv2.imread("/content/images.jpg")
cv2_imshow(original_image)
cv2.waitKey(0)

# create a sharpening kernel
sharpen_filter = np.array([[0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]])

# applying kernels to the input image to get the sharpened image
sharp_image = cv2.filter2D(original_image, -1, sharpen_filter)
cv2_imshow(sharp_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
import cv2
import numpy as np
from PIL import Image

# Load the image and convert it to RGB
img = Image.open("/content/images.jpg")
img = img.convert("RGB")

# Convert the image to a NumPy array
img_array = np.asarray(img)

# Sharpen the image
sharpen_filter = np.array([[0, -1, 0],
                           [-1, 5, -1],
                           [0, -1, 0]])
sharp_image = cv2.filter2D(img_array, -1, sharpen_filter)

# Save the sharpened image
cv2.imwrite("flower_image_altered.jpg", sharp_image)
# Out:
# True

# %%
import cv2
import numpy as np

img = cv2.imread("/content/images (1).jpg")

# %%
rows, cols = img.shape[:2]

# %%
kernel_25 = np.ones((25,25),np.float32)/625.0
output_kernel = cv2.filter2D(img,-1,kernel_25)

# %%
output_blur = cv2.blur(img,(25,25))
output_box = cv2.boxFilter(img,-1,(5,5),normalize=False)

# %%
output_gaus = cv2.GaussianBlur(img, (5,5),0)

# %%
output_med = cv2.medianBlur(img,5)

# %%
output_bil = cv2.bilateralFilter(img,5,6,6)

# %%
cv2_imshow(output_kernel)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
cv2_imshow(output_bil)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("/content/images (1).jpg")

# %%
gausssian_blur = cv2.GaussianBlur(img, (7,7),2)

sharp1= cv2.addWeighted(img,1.5,gausssian_blur,-0.5,0)
sharp2= cv2.addWeighted(img,3.5,gausssian_blur,-2.5,0)
sharp3= cv2.addWeighted(img,7.5,gausssian_blur,-6.5,0)

# %%
cv2_imshow(sharp3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
